# %%
# !pip install transformers sentencepiece accelerate
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 26.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 28.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 39.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 6.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 5.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 7.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 33.9 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
# ...

# %%
# Step 1: Import required modules
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM, pipeline

#  Step 2: Load NLLB model and tokenizer
model = AutoModelForSeq2SeqLM.from_pretrained('facebook/nllb-200-distilled-600M')
tokenizer = AutoTokenizer.from_pretrained('facebook/nllb-200-distilled-600M')

#Step 3: Define translation function
def translate(input_text, src_lang='eng_Latn', target_lang='kan_Knda'):
    translator = pipeline(
        task='translation',
        model=model,
        tokenizer=tokenizer,
        src_lang=src_lang,
        tgt_lang=target_lang,
        max_length=400
    )
    return translator(input_text)[0]['translation_text']

# Step 4: Input sentence to translate
input_text = " Education is the most powerful weapon"

# Step 5: Translate into multiple languages
kannada = translate(input_text, target_lang='kan_Knda')
hindi = translate(input_text, target_lang='hin_Deva')


# Step 6: Display the outputs
print(f"Kannada translation: {kannada}\n")
print(f"Hindi translation: {hindi}\n")
# Out:
# Device set to use cpu
# Device set to use cpu
# Kannada translation: ಶಿಕ್ಷಣವು ಅತ್ಯಂತ ಶಕ್ತಿಶಾಲಿ ಆಯುಧವಾಗಿದೆ
#
# Hindi translation: शिक्षा सबसे शक्तिशाली हथियार है
